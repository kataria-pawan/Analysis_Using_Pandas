# %%
import pandas as pd

# %%
filepath = "C:/Users/Pawan Kataria/Downloads/CPI2022_GlobalResultsTrends.xlsx"
df = pd.read_excel(filepath)
print(df)
# Out:
#     Corruption Perceptions Index 2022: Global scores Unnamed: 1 Unnamed: 2  \
# 0                                                NaN        NaN        NaN
# 1                                Country / Territory       ISO3     Region
# 2                                        Afghanistan        AFG         AP
# 3                                            Albania        ALB        ECA
# 4                                            Algeria        DZA       MENA
# ..                                               ...        ...        ...
# 177                                        Venezuela        VEN        AME
# 178                                          Vietnam        VNM         AP
# 179                                            Yemen        YEM       MENA
# 180                                           Zambia        ZMB        SSA
# 181                                         Zimbabwe        ZWE        SSA
#
# ...

# %%
df = pd.read_excel(filepath, header=2)
df
# Out:
#     Country / Territory ISO3 Region  CPI score 2022  Rank  Standard error  \
# 0           Afghanistan  AFG     AP              24   150        6.299999
# 1               Albania  ALB    ECA              36   101        1.316355
# 2               Algeria  DZA   MENA              33   116        1.673809
# 3                Angola  AGO    SSA              33   116        2.807703
# 4             Argentina  ARG    AME              38    94        2.334808
# ..                  ...  ...    ...             ...   ...             ...
# 175           Venezuela  VEN    AME              14   177        1.296945
# 176             Vietnam  VNM     AP              42    77        1.497007
# 177               Yemen  YEM   MENA              16   176        1.975074
# 178              Zambia  ZMB    SSA              33   116        1.495884
# 179            Zimbabwe  ZWE    SSA              23   157        1.532080
#
#      Number of sources  Lower CI  Upper CI  African Development Bank CPIA  \
# ...

# %%
df.head()
# Out:
#   Country / Territory ISO3 Region  CPI score 2022  Rank  Standard error  \
# 0         Afghanistan  AFG     AP              24   150        6.299999
# 1             Albania  ALB    ECA              36   101        1.316355
# 2             Algeria  DZA   MENA              33   116        1.673809
# 3              Angola  AGO    SSA              33   116        2.807703
# 4           Argentina  ARG    AME              38    94        2.334808
#
#    Number of sources  Lower CI  Upper CI  African Development Bank CPIA  ...  \
# 0                  4  13.66800  34.33200                            NaN  ...
# 1                  8  33.84118  38.15882                            NaN  ...
# 2                  6  30.25495  35.74504                            NaN  ...
# 3                  7  28.39537  37.60463                            NaN  ...
# 4                  7  34.17091  41.82909                            NaN  ...
#
#    Economist Intelligence Unit Country Ratings  \
# ...

# %% [markdown]
# What five countries were least corrupt in 2022?

# %%
df["CPI score 2022"]
# Out:
# 0      24
# 1      36
# 2      33
# 3      33
# 4      38
#        ..
# 175    14
# 176    42
# 177    16
# 178    33
# 179    23
# Name: CPI score 2022, Length: 180, dtype: int64

# %%
df["CPI score 2022"].sort_values(ascending=False)
# Out:
# 42     90
# 55     87
# 116    87
# 121    84
# 154    83
#        ..
# 177    16
# 175    14
# 156    13
# 149    13
# 147    12
# Name: CPI score 2022, Length: 180, dtype: int64

# %%
df.set_index("Country / Territory")["CPI score 2022"].sort_values(ascending=False).head()
# Out:
# Country / Territory
# Denmark        90
# Finland        87
# New Zealand    87
# Norway         84
# Sweden         83
# Name: CPI score 2022, dtype: int64

# %% [markdown]
# What five countries were most corrupt in 2022?

# %%
df.set_index('Country / Territory')["CPI score 2022"].sort_values(ascending=True).head()
# Out:
# Country / Territory
# Somalia        12
# Syria          13
# South Sudan    13
# Venezuela      14
# Yemen          16
# Name: CPI score 2022, dtype: int64

# %% [markdown]
# Which region of the world was least corrupt?

# %%
df.groupby('Region')["CPI score 2022"].mean()
# Out:
# Region
# AME      42.968750
# AP       45.129032
# ECA      35.210526
# MENA     37.500000
# SSA      32.387755
# WE/EU    65.516129
# Name: CPI score 2022, dtype: float64

# %%
df.groupby('Region')["CPI score 2022"].median()
# Out:
# Region
# AME      39.5
# AP       40.0
# ECA      36.0
# MENA     39.0
# SSA      30.0
# WE/EU    62.0
# Name: CPI score 2022, dtype: float64

# %%
df.groupby('Region')["CPI score 2022"].mean().sort_values()
# Out:
# Region
# SSA      32.387755
# ECA      35.210526
# MENA     37.500000
# AME      42.968750
# AP       45.129032
# WE/EU    65.516129
# Name: CPI score 2022, dtype: float64

# %%
df.groupby('Region')["CPI score 2022"].mean().idxmax()
# Out:
# 'WE/EU'

# %% [markdown]
# Which five countries have made the greatest improvement in 10 years, between the 2012 report and the 2022 report?

# %%
df = pd.read_excel(filepath, sheet_name=2, header=2)
df
# Out:
#                    Country ISO3 Region  CPI 2022  CPI 2012  Unnamed: 5  \
# 0                   Angola  AGO    SSA        33        22         NaN
# 1                  Armenia  ARM    ECA        46        34         NaN
# 2                Australia  AUS     AP        75        85         NaN
# 3   Bosnia and Herzegovina  BIH    ECA        34        42         NaN
# 4                   Canada  CAN    AME        74        84         NaN
# 5            Cote d'Ivoire  CIV    SSA        37        29         NaN
# 6                   Cyprus  CYP  WE/EU        52        66         NaN
# 7           Czech Republic  CZE  WE/EU        56        49         NaN
# 8                  Estonia  EST  WE/EU        74        64         NaN
# 9                 Ethiopia  ETH    SSA        38        33         NaN
# 10                  Greece  GRC  WE/EU        52        36         NaN
# 11               Guatemala  GTM    AME        24        33         NaN
# ...

# %%
df = pd.read_excel(filepath, sheet_name=2, header=2, usecols=[0,1,2,3,4])
df.head(3)
# Out:
#      Country ISO3 Region  CPI 2022  CPI 2012
# 0     Angola  AGO    SSA        33        22
# 1    Armenia  ARM    ECA        46        34
# 2  Australia  AUS     AP        75        85

# %%
df['change'] = df['CPI 2022'] - df['CPI 2012']
df['change'].sort_values(ascending=False).head()
# Out:
# 26    18
# 10    16
# 16    14
# 31    14
# 12    12
# Name: change, dtype: int64

# %%
df.set_index('Country')['change'].sort_values(ascending=False).head()
# Out:
# Country
# Seychelles    18
# Greece        16
# Italy         14
# Uzbekistan    14
# Guyana        12
# Name: change, dtype: int64
